# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("qmarva/cubicasa5k")

print("Path to dataset files:", path)
# Out:
# Resuming download from 5167382528 bytes (312267688 bytes left)...
# Resuming download from https://www.kaggle.com/api/v1/datasets/download/qmarva/cubicasa5k?dataset_version_number=4 (5167382528/5479650216) bytes left.
# 100%|██████████| 5.10G/5.10G [02:19<00:00, 2.24MB/s]
# Extracting files...
# Path to dataset files: C:\Users\USER\.cache\kagglehub\datasets\qmarva\cubicasa5k\versions\4

# %%
# sample image showing

import os
import matplotlib.pyplot as plt
import matplotlib.image as mpimg


# Walk through the directory and find image files
image_extensions = ('.png', '.jpg', '.jpeg')
image_files = [os.path.join(root, file)
               for root, dirs, files in os.walk(path)
               for file in files
               if file.lower().endswith(image_extensions)]

# Display the first 5 images
for img_path in image_files[:5]:
    img = mpimg.imread(img_path)
    plt.figure(figsize=(6, 6))
    plt.imshow(img)
    plt.axis('off')
    plt.title(img_path)
    plt.show()

# %%
# yolo detect train data=data.yaml model=yolov8n.pt epochs=50 imgsz=640
